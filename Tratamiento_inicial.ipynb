# %% [markdown]
# <a href="https://colab.research.google.com/github/rcortes100/wide-binaries/blob/main/Tratamiento_inicial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Esto es una prueba para el manejo de datos en Pandas

# %%
import pandas as pd

# %%
ruta = '/content/drive/MyDrive/wide_bin/latest-result.csv'
df = pd.read_csv(ruta)

# %%
duplicate_rows = df[df.duplicated(subset=['source_id_1'], keep=False)]

# %%
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [source_id_1, source_id_2, ra_1, dec_1, ra_2, dec_2, ra_err_1, dec_err_1, ra_err_2, dec_err_2, parallax_1, parallax_2, par_over_err_1, par_over_err_2, pmra_1, pmdec_1, pmra_2, pmdec_2, pmra_err_1, pmdec_err_1, pmra_err_2, pmdec_err_2, rad_vel_1, rad_vel_2, rad_vel_err_1, rad_vel_err_2, phot_g_1, phot_g_2, phot_g_over_err_1, phot_g_over_err_2, phot_bp_1, phot_bp_2, phot_bp_over_err_1, phot_bp_over_err_2, phot_rp_1, phot_rp_2, phot_rp_1.1, phot_rp_2.1, astro_chi2_al_1, astro_chi2_al_2, astro_chi2_al_1.1, astro_chi2_al_2.1, astro_n_goodobs_al_1, astro_n_goodobs_al_2, phot_bp_rp_xs_1, phot_bp_rp_xs_2, rv_nb_tran_1, rv_nb_tran_2, pairdistance, angular_distance]
# Index: []
#
# [0 rows x 50 columns]

# %%
# Assuming 'column_name' is the column to check for duplicates
df_limpia = df.drop_duplicates(subset=['source_id_1'], keep=False)
df_limpia = df_limpia.reset_index(drop=True)
