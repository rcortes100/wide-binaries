# %%
# %matplotlib widget
from binaries import *

# %%
je = pd.read_pickle('../data_processed/jim_es_final_selection.pkl')

je['dist_mod_x'] = -5*(np.log10(1E-3*je.parallax_x)+1)
je['g_abs_x']    = je.phot_g_mean_mag_x - je.dist_mod_x

je['dist_mod_y'] = -5*(np.log10(1E-3*je.parallax_y)+1)
je['g_abs_y']   = je.phot_g_mean_mag_y - je.dist_mod_y

# %%
fig, ax2 = plt.subplots()
fnt = 10
dotsize = 1
ax2.invert_yaxis()

ax2.set_xlabel('G$_{BP}$-G$_{RP}$',fontsize=fnt)
#ax2.set_ylabel('M$_G$',fontsize=fnt,labelpad=0)

#ax2.plot(subtab.BP_RP1,subtab.G_abs1, 
ax2.plot(je.bp_rp_x,je.g_abs_x,
         'o',ms=dotsize, label='$M_G$ pri')
#ax2.plot(subtab.BP_RP2,subtab.G_abs2 +3,
ax2.plot(je.bp_rp_y,je.g_abs_y +3, 
         'o',ms=dotsize, label='$M_G$ sec +3')
ax2.legend(markerscale=1)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
for i in je.columns:
    print(i)
# Out:
# source_id_x
# ra_x
# ra_error_x
# dec_x
# dec_error_x
# parallax_x
# parallax_error_x
# pmra_x
# pmra_error_x
# pmdec_x
# pmdec_error_x
# duplicated_source_x
# phot_g_mean_mag_x
# phot_bp_mean_mag_x
# phot_rp_mean_mag_x
# bp_rp_x
# bp_g_x
# g_rp_x
# radial_velocity_x
# radial_velocity_error_x
# teff_val_x
# col_ra_x
# dec.1_x
# dis_x
# ra1_x
# dec1_x
# source_tycho2_x
# groupid
# groupsize
# sep_ang
# sep_sky
# radial_velocity.1_x
# radial_velocity_error.1_x
# parallax.1_x
# parallax_total_error_x
# pmra_corrected_x
# pmra_corrected_error_x
# pmdec_corrected_x
# pmdec_corrected_error_x
# phot_g_mean_mag.1_x
# phot_bp_mean_mag.1_x
# phot_rp_mean_mag.1_x
# ruwe_x
# hrv_x
# e_hrv_x
# d_g_x
# teff_x
# teff_error_x
# av_x
# mass_x
# mass_error_x
# u_x
# u_error_x
# td_x
# td_error_x
# tms_x
# tms_error_x
# ecac_x
# source_id_y
# ra_y
# ra_error_y
# dec_y
# dec_error_y
# parallax_y
# parallax_error_y
# pmra_y
# pmra_error_y
# pmdec_y
# pmdec_error_y
# duplicated_source_y
# ...
