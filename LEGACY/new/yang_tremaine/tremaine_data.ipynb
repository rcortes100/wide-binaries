# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib nbagg

# %%
from binaries import *

# %%
len(tremaine[0])
RMS_trem
# Out:
# 28

# %%
plt.plot(DIST_trem ,RMS_trem)
x = np.linspace(-4,3,100)

# %%
new = pd.DataFrame({'log_r(pc)' : x ,
                    'V1D(km/s)' : f2(x)})

# %%
new['log_r(pc)'] = new['log_r(pc)'] + np.log10(1.7)

# %%
new['V1D(km/s)'] = new['V1D(km/s)'] + np.log10(0.05)

# %%
plt.plot(new['log_r(pc)'],new['V1D(km/s)'])

# %%
new.to_csv('tremaine_table.csv',index=False)

# %%
plt.plot(xspan,trem_line(xspan))
# Out:
# /home/lupido/MEGAsync/Documentos/ASTRO/Doctorado/2o_semestre/CANARIAS_GAIA/new/yang_tremaine/binaries.py:295: RuntimeWarning: invalid value encountered in log10
#   return a*10**(f2(np.log10(r/b)))
